# %%
# %pip install imageio
# %pip install git+https://github.com/tensorflow/docs

import os
import time
from IPython import display

import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np
from PIL import Image
from skimage.transform import resize
import zipfile

import imageio
import glob

import tensorflow as tf
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: imageio in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from imageio) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio) (7.1.2)
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-nt05cux1
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-nt05cux1
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (0.12.0)
# Requirement already satisfied: protobuf>=3.14 in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (3.17.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (3.13)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.14->tensorflow-docs==0.0.0.dev0) (1.15.0)

# %%
# !unzip  "/content/poke/archive.zip" -d "/content/poke/"
# Out:
# Archive:  /content/poke/archive.zip
#    creating: /content/poke/archive/
#    creating: /content/poke/archive/images/
#    creating: /content/poke/archive/images/images/
#   inflating: /content/poke/archive/images/images/$rrr.png
#   inflating: /content/poke/archive/images/images/1.png
#   inflating: /content/poke/archive/images/images/2.png
#   inflating: /content/poke/archive/images/images/3.png
#   inflating: /content/poke/archive/images/images/34.png
#   inflating: /content/poke/archive/images/images/459874.png
#   inflating: /content/poke/archive/images/images/46.png
#   inflating: /content/poke/archive/images/images/464.png
#   inflating: /content/poke/archive/images/images/466.png
#   inflating: /content/poke/archive/images/images/46854.png
#   inflating: /content/poke/archive/images/images/49684.png
#   inflating: /content/poke/archive/images/images/5.png
#   inflating: /content/poke/archive/images/images/5464.png
#   inflating: /content/poke/archive/images/images/55.png
#   inflating: /content/poke/archive/images/images/564.png
#   inflating: /content/poke/archive/images/images/56rr.png
#   inflating: /content/poke/archive/images/images/57.png
#   inflating: /content/poke/archive/images/images/6.png
#   inflating: /content/poke/archive/images/images/64654.png
#   inflating: /content/poke/archive/images/images/84798.png
#   inflating: /content/poke/archive/images/images/879.png
#   inflating: /content/poke/archive/images/images/Aged_Smelter_Sword.png
#   inflating: /content/poke/archive/images/images/anris_straight_sword-icon.png
#   inflating: /content/poke/archive/images/images/aquamarine_dagger.png
#   inflating: /content/poke/archive/images/images/arced_sword.png
#   inflating: /content/poke/archive/images/images/arstors_spear-icon.png
#   inflating: /content/poke/archive/images/images/ashen_warrior_sword.png
#   inflating: /content/poke/archive/images/images/astora_greatsword.png
#   inflating: /content/poke/archive/images/images/astora_straight_sword-icon.png
#   inflating: /content/poke/archive/images/images/Baby's_Nail.png
#   inflating: /content/poke/archive/images/images/bandits_knife (2).png
#   inflating: /content/poke/archive/images/images/Bandits_Knife.png
#   inflating: /content/poke/archive/images/images/barbed_straight_sword-icon.png
#   inflating: /content/poke/archive/images/images/bastard_sword (2).png
#   inflating: /content/poke/archive/images/images/Bastard_Sword.png
#   inflating: /content/poke/archive/images/images/Berserker_Blade.png
#   inflating: /content/poke/archive/images/images/bewitched_alonne_sword.png
#   inflating: /content/poke/archive/images/images/bl.png
#   inflating: /content/poke/archive/images/images/Blacksteel_Katana.png
#   inflating: /content/poke/archive/images/images/black_blade.png
#   inflating: /content/poke/archive/images/images/Black_Dragon_Sword.png
#   inflating: /content/poke/archive/images/images/Black_Flamestone_Dagger.png
#   inflating: /content/poke/archive/images/images/black_knight_greatsword (2).png
#   inflating: /content/poke/archive/images/images/Black_Knight_Greatsword.png
#   inflating: /content/poke/archive/images/images/black_knight_sword-icon.png
#   inflating: /content/poke/archive/images/images/Black_Knight_Ultra_Greatsword.png
#   inflating: /content/poke/archive/images/images/Black_Scorpion_Stinger.png
#   inflating: /content/poke/archive/images/images/Blind.png
#   inflating: /content/poke/archive/images/images/Blueblood_Sword.png
#   inflating: /content/poke/archive/images/images/Bluemoon_Greatsword.png
#   inflating: /content/poke/archive/images/images/Blue_Dagger.png
#   inflating: /content/poke/archive/images/images/Blue_Flame.png
#   inflating: /content/poke/archive/images/images/brigand_twindaggers-icon.png
#   inflating: /content/poke/archive/images/images/broadsword-icon.png
#   inflating: /content/poke/archive/images/images/Broadsword.png
#   inflating: /content/poke/archive/images/images/Broad_Sword.png
#   inflating: /content/poke/archive/images/images/BrokenStraightSword.png
#   inflating: /content/poke/archive/images/images/Broken_Straight_Sword.png
#   inflating: /content/poke/archive/images/images/Broken_Sword.png
#   inflating: /content/poke/archive/images/images/Broken_Thief_Sword.png
#   inflating: /content/poke/archive/images/images/butcher_knife-icon.png
#   inflating: /content/poke/archive/images/images/carthus_curved_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/carthus_curved_sword-icon.png
#   inflating: /content/poke/archive/images/images/carthus_shotel-icon.png
#   inflating: /content/poke/archive/images/images/cathedral_knight_greatsword.png
#   inflating: /content/poke/archive/images/images/ccc.png
#   inflating: /content/poke/archive/images/images/chaos_blade (2).png
#   inflating: /content/poke/archive/images/images/Chaos_Blade.png
#   inflating: /content/poke/archive/images/images/Chaos_Rapier.png
#   inflating: /content/poke/archive/images/images/charred_loyce_greatsword.png
#   inflating: /content/poke/archive/images/images/claymore-icon.png
#   inflating: /content/poke/archive/images/images/Claymore.png
#   inflating: /content/poke/archive/images/images/cleric's_candlestick-icon.png
#   inflating: /content/poke/archive/images/images/cms.png
#   inflating: /content/poke/archive/images/images/corvian_greatknife-icon.png
#   inflating: /content/poke/archive/images/images/crow_quills-icon.png
#   inflating: /content/poke/archive/images/images/crypt_blacksword.png
#   inflating: /content/poke/archive/images/images/crystal_sages_rapier-icon.png
#   inflating: /content/poke/archive/images/images/Curved_Nil_Greatsword.png
#   inflating: /content/poke/archive/images/images/Dagger.png
#   inflating: /content/poke/archive/images/images/Dagger2.png
#   inflating: /content/poke/archive/images/images/Dagger_1.png
#   inflating: /content/poke/archive/images/images/dancers_enchanted_swords1.png
#   inflating: /content/poke/archive/images/images/darkdrift-icon.png
#   inflating: /content/poke/archive/images/images/Darkdrift.png
#   inflating: /content/poke/archive/images/images/dark_sword-icon.png
#   inflating: /content/poke/archive/images/images/Defender_Greatsword.png
#   inflating: /content/poke/archive/images/images/demon's_scar.png
#   inflating: /content/poke/archive/images/images/Dragon_Bone_Smasher.png
#   inflating: /content/poke/archive/images/images/dragon_greatsword.png
#   inflating: /content/poke/archive/images/images/Drakeblood%20Greatsword.png
#   inflating: /content/poke/archive/images/images/drakeblood_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/Drakekeepers_Sword.png
#   inflating: /content/poke/archive/images/images/drakekeepers_ultra_greatsword.png
#   inflating: /content/poke/archive/images/images/drakewing_ultra_greatsword.png
#   inflating: /content/poke/archive/images/images/Drangleic_Sword.png
#   inflating: /content/poke/archive/images/images/Eleum_Loyce.png
#   inflating: /content/poke/archive/images/images/Epee_Rapier.png
#   inflating: /content/poke/archive/images/images/Espada_Ropera.png
#   inflating: /content/poke/archive/images/images/Estoc (2).png
#   inflating: /content/poke/archive/images/images/estoc-icon.png
#   inflating: /content/poke/archive/images/images/Estoc.png
#   inflating: /content/poke/archive/images/images/executioners_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/exile_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/Falchion (2).png
#   inflating: /content/poke/archive/images/images/Falchion (3).png
#   inflating: /content/poke/archive/images/images/falchion-icon.png
#   inflating: /content/poke/archive/images/images/falchion.png
#   inflating: /content/poke/archive/images/images/farron_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/fff.png
#   inflating: /content/poke/archive/images/images/fifhiuff.png
#   inflating: /content/poke/archive/images/images/firelink_greatsword1.png
#   inflating: /content/poke/archive/images/images/Flamberge.png
#   inflating: /content/poke/archive/images/images/flameberge-icon.png
#   inflating: /content/poke/archive/images/images/follower_sabre.png
#   inflating: /content/poke/archive/images/images/Foot_Soldier_Sword.png
#   inflating: /content/poke/archive/images/images/frayed_blade.png
#   inflating: /content/poke/archive/images/images/fume_sword.png
#   inflating: /content/poke/archive/images/images/fume_ultra_greatsword (2).png
#   inflating: /content/poke/archive/images/images/fume_ultra_greatsword.png
#   inflating: /content/poke/archive/images/images/gaels_greatsword.png
#   inflating: /content/poke/archive/images/images/Geri's_Stiletto.png
#   inflating: /content/poke/archive/images/images/ggg.png
#   inflating: /content/poke/archive/images/images/gotthard_twinswords-icon.png
#   inflating: /content/poke/archive/images/images/gr.png
#   inflating: /content/poke/archive/images/images/greatsword-icon.png
#   inflating: /content/poke/archive/images/images/Greatsword.png
#   inflating: /content/poke/archive/images/images/greatsword_of_judgment-icon.png
#   inflating: /content/poke/archive/images/images/greatsword_of_the_forlorn.png
#   inflating: /content/poke/archive/images/images/Great_Sword.png
#   inflating: /content/poke/archive/images/images/handmaids_dagger-icon.png
#   inflating: /content/poke/archive/images/images/harald_curved_greatsword.png
#   inflating: /content/poke/archive/images/images/harpe-icon.png
#   inflating: /content/poke/archive/images/images/Heide_Knight_Sword.png
#   inflating: /content/poke/archive/images/images/Hiltless.png
#   inflating: /content/poke/archive/images/images/hollowslayer_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/iaito.png
#   inflating: /content/poke/archive/images/images/Ice_Rapier.png
#   inflating: /content/poke/archive/images/images/ihiu.png
#   inflating: /content/poke/archive/images/images/iojoi.png
#   inflating: /content/poke/archive/images/images/iojoij.png
#   inflating: /content/poke/archive/images/images/IrithyllStraightSword.png
#   inflating: /content/poke/archive/images/images/irithyll_rapier-icon.png
#   inflating: /content/poke/archive/images/images/iugiu.png
#   inflating: /content/poke/archive/images/images/Ivory_King_Ultra_Greatsword.png
#   inflating: /content/poke/archive/images/images/ivory_straight_sword.png
#   inflating: /content/poke/archive/images/images/jb.png
#   inflating: /content/poke/archive/images/images/jbi.png
#   inflating: /content/poke/archive/images/images/jhgfj.png
#   inflating: /content/poke/archive/images/images/Key_to_the_Embedded.png
#   inflating: /content/poke/archive/images/images/Kilij.png
#   inflating: /content/poke/archive/images/images/kings_ultra_greatsword.png
#   inflating: /content/poke/archive/images/images/kjgk.png
#   inflating: /content/poke/archive/images/images/kjh.png
#   inflating: /content/poke/archive/images/images/kjhb.png
#   inflating: /content/poke/archive/images/images/kl.png
#   inflating: /content/poke/archive/images/images/Knight_Sword.png
#   inflating: /content/poke/archive/images/images/Kris_Blade.png
#   inflating: /content/poke/archive/images/images/Large_Sword_of_Searching.png
#   inflating: /content/poke/archive/images/images/lkjpoikj.png
#   inflating: /content/poke/archive/images/images/longsword-icon.png
#   inflating: /content/poke/archive/images/images/Longsword.png
#   inflating: /content/poke/archive/images/images/Long_Sword.png
#   inflating: /content/poke/archive/images/images/lorians_greatsword.png
#   inflating: /content/poke/archive/images/images/lost-sinner-s-sword-lg.png
#   inflating: /content/poke/archive/images/images/lothrics_holy_sword-icon.png
#   inflating: /content/poke/archive/images/images/lothric_knight_greatsword.png
#   inflating: /content/poke/archive/images/images/lothric_knight_sword.png
#   inflating: /content/poke/archive/images/images/Magic_Sword_Makoto.png
#   inflating: /content/poke/archive/images/images/Mail_Breaker (2).png
#   inflating: /content/poke/archive/images/images/mail_breaker-icon.png
#   inflating: /content/poke/archive/images/images/Mail_Breaker.png
#   inflating: /content/poke/archive/images/images/Manikin_Knife.png
#   inflating: /content/poke/archive/images/images/Manikin_Sabre.png
#   inflating: /content/poke/archive/images/images/Manslayer.png
#   inflating: /content/poke/archive/images/images/mastodon_greatsword_ds2.png
#   inflating: /content/poke/archive/images/images/Melu_Scimitar.png
#   inflating: /content/poke/archive/images/images/Mirrah_Greatsword.png
#   inflating: /content/poke/archive/images/images/mlkjoi.png
#   inflating: /content/poke/archive/images/images/Monastery_Scimitar.png
#   inflating: /content/poke/archive/images/images/Moonlight_Greatsword.png
#   inflating: /content/poke/archive/images/images/moonlight_greatsword1.png
#   inflating: /content/poke/archive/images/images/morion_blade-icon.png
#   inflating: /content/poke/archive/images/images/murakumo (2).png
#   inflating: /content/poke/archive/images/images/Murakumo.png
#   inflating: /content/poke/archive/images/images/murky_hand_scythe.png
#   inflating: /content/poke/archive/images/images/Mythas_Bent_Blade.png
#   inflating: /content/poke/archive/images/images/Needle_of_Eternal_Agony.png
#   inflating: /content/poke/archive/images/images/noi.png
#   inflating: /content/poke/archive/images/images/ogygug.png
#   inflating: /content/poke/archive/images/images/oih.png
#   inflating: /content/poke/archive/images/images/oihiu.png
#   inflating: /content/poke/archive/images/images/oijnoin.png
#   inflating: /content/poke/archive/images/images/Old_Knight_Greatsword.png
#   inflating: /content/poke/archive/images/images/Old_Knight_Ultra_Greatsword.png
#   inflating: /content/poke/archive/images/images/Old_Mirrah_Greatsword.png
#   inflating: /content/poke/archive/images/images/Old_Wolf_Curved_Sword.png
#   inflating: /content/poke/archive/images/images/onikiri_and_ubadachi.png
#   inflating: /content/poke/archive/images/images/onyx_blade-icon.png
#   inflating: /content/poke/archive/images/images/painting_guardians_curved_sword1.png
#   inflating: /content/poke/archive/images/images/Parrying_Dagger (2).png
#   inflating: /content/poke/archive/images/images/parrying_dagger-icon.png
#   inflating: /content/poke/archive/images/images/Parrying_Dagger.png
#   inflating: /content/poke/archive/images/images/Penetrating_sword.PNG
#   inflating: /content/poke/archive/images/images/poij.png
#   inflating: /content/poke/archive/images/images/poijoi.png
#   inflating: /content/poke/archive/images/images/poj.png
#   inflating: /content/poke/archive/images/images/pojkpo.png
#   inflating: /content/poke/archive/images/images/pojoi.png
#   inflating: /content/poke/archive/images/images/pok.png
#   inflating: /content/poke/archive/images/images/possessed_armor_sword.png
#   inflating: /content/poke/archive/images/images/profane_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/Pursuers_Ultra_Greatsword.png
#   inflating: /content/poke/archive/images/images/puzzling_stone_sword.png
#   inflating: /content/poke/archive/images/images/Rapier (2).png
#   inflating: /content/poke/archive/images/images/rapier-icon.png
#   inflating: /content/poke/archive/images/images/Rapier.png
#   inflating: /content/poke/archive/images/images/Red_Rust_Scimitar.png
#   inflating: /content/poke/archive/images/images/Red_Rust_Sword.png
#   inflating: /content/poke/archive/images/images/Retainers_Short_Sword.png
#   inflating: /content/poke/archive/images/images/ricards_rapier-icon.png
#   inflating: /content/poke/archive/images/images/Ricards_Rapier.png
#   inflating: /content/poke/archive/images/images/ringed_knight_paired_greatswords.png
#   inflating: /content/poke/archive/images/images/ringed_knight_straight_sword.png
#   inflating: /content/poke/archive/images/images/rotten_ghru_curved_sword1.png
#   inflating: /content/poke/archive/images/images/rotten_ghru_dagger-icon.png
#   inflating: /content/poke/archive/images/images/Royal_Dirk.png
#   inflating: /content/poke/archive/images/images/Royal_Greatsword.png
#   inflating: /content/poke/archive/images/images/Rulers_Sword.png
#   inflating: /content/poke/archive/images/images/Rune_Sword.png
#   inflating: /content/poke/archive/images/images/scholars_candlestick-icon.png
#   inflating: /content/poke/archive/images/images/Scimitar (2).png
#   inflating: /content/poke/archive/images/images/Scimitar.png
#   inflating: /content/poke/archive/images/images/Scimitar2.png
#   inflating: /content/poke/archive/images/images/Secret_Dagger.png
#   inflating: /content/poke/archive/images/images/Sellsword_Twinblade-icon.png
#   inflating: /content/poke/archive/images/images/Shadow_Dagger.png
#   inflating: /content/poke/archive/images/images/Shortsword.png
#   inflating: /content/poke/archive/images/images/Shortsword2.png
#   inflating: /content/poke/archive/images/images/Short_Sword.png
#   inflating: /content/poke/archive/images/images/Shotel (2).png
#   inflating: /content/poke/archive/images/images/Shotel (3).png
#   inflating: /content/poke/archive/images/images/shotel-icon.png
#   inflating: /content/poke/archive/images/images/shotel.png
#   inflating: /content/poke/archive/images/images/Smelter_Sword.png
#   inflating: /content/poke/archive/images/images/Spiders_Silk.png
#   inflating: /content/poke/archive/images/images/Spider_Fang.png
#   inflating: /content/poke/archive/images/images/Spiral_Rapier.png
#   inflating: /content/poke/archive/images/images/storm_curved_sword.png
#   inflating: /content/poke/archive/images/images/storm_ruler-icon.png
#   inflating: /content/poke/archive/images/images/sunlight_straight_sword-icon.png
#   inflating: /content/poke/archive/images/images/Sun_Sword.png
#   inflating: /content/poke/archive/images/images/tailbone_short_sword-icon.png
#   inflating: /content/poke/archive/images/images/Thief_Dagger.png
#   inflating: /content/poke/archive/images/images/Thorned_Greatsword.png
#   inflating: /content/poke/archive/images/images/twin_princess_greatsword1.png
#   inflating: /content/poke/archive/images/images/Uchigatana (2).png
#   inflating: /content/poke/archive/images/images/uchigatana-icon.png
#   inflating: /content/poke/archive/images/images/Uchigatana.png
#   inflating: /content/poke/archive/images/images/Umbral_Dagger.png
#   inflating: /content/poke/archive/images/images/uoih.png
#   inflating: /content/poke/archive/images/images/valorheart-icon.png
#   inflating: /content/poke/archive/images/images/Varangian_Sword.png
#   inflating: /content/poke/archive/images/images/warden_twinblades-icon.png
#   inflating: /content/poke/archive/images/images/Warped_Sword.png
#   inflating: /content/poke/archive/images/images/washing_pole-icon.png
#   inflating: /content/poke/archive/images/images/Washing_Pole.png
#   inflating: /content/poke/archive/images/images/Watcher_Greatsword.png
#   inflating: /content/poke/archive/images/images/wolf_knights_greatsword-icon.png
#   inflating: /content/poke/archive/images/images/wolnirs_holy_sword-icon.png
#   inflating: /content/poke/archive/images/images/Yellow_Quartz_Longsword.png
#   inflating: /content/poke/archive/images/images/yg.png
#   inflating: /content/poke/archive/images/images/zweihander (2).png
#   inflating: /content/poke/archive/images/images/Zweihander.png
#   inflating: /content/poke/archive/images/images/é64986.png
#   inflating: /content/poke/archive/images/images/éjbnuyig.png

# %%
train_dir = "/content/poke/archive/images/images/"
fnames = os.listdir(train_dir)
filepaths = [train_dir + fname for fname in fnames]

# %%
IMG_SIZE = 80
BATCH_SIZE = 4
BUFFER_SIZE = 276

# %%
def modify_background(filepath):
    png = Image.open(filepath).convert('RGBA')
    png.load() # required for png.split()

    modified_img = Image.new("RGB", png.size, (0, 0, 0))   # (0, 0, 0) for a black background
    modified_img.paste(png, mask=png.split()[-1])          # the last index is the alpha channel
    
    return modified_img

# %%
def preprocess(filepath):
    img = modify_background(filepath)
    img = tf.keras.preprocessing.image.img_to_array(img)    # converting the PIL image into a Numpy array
    img = resize(img, (80, 80))                             # we distort but we make the GAN's work easier (and ours of course)
    img = (img - 127.5) / 127.5                             # rescaling the RGB values to be between -1 and 1
    return img

# %%
og = Image.open('/content/poke/archive/images/images/Bandits_Knife.png')
og
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=48x75 at 0x7FF52681A310>

# %%
modified = preprocess('/content/poke/archive/images/images/Bandits_Knife.png')
modified = tf.keras.preprocessing.image.array_to_img(modified)    # converting the Numpy array back into a PIL image
modified
# Out:
# <PIL.Image.Image image mode=RGB size=80x80 at 0x7FF52681A3D0>

# %%
def configure_for_performance(dataset):
    dataset = dataset.filter(lambda x: x[0, 0, 0] == -1)
    dataset = dataset.cache()
    dataset = dataset.shuffle(BUFFER_SIZE)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE) 
    return dataset

# %%
preprocessed_imgs = list(map(preprocess, filepaths))                    # preprocessing the data
train_dataset = tf.data.Dataset.from_tensor_slices(preprocessed_imgs)   # creating the dataset                    
train_dataset = configure_for_performance(train_dataset)                #

# %%
def make_generator_model():
    model = tf.keras.Sequential() 
    model.add(layers.Dense((IMG_SIZE // 4)*(IMG_SIZE // 4)*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((IMG_SIZE // 4, IMG_SIZE // 4, 256)))
    assert model.output_shape == (None, IMG_SIZE/4, IMG_SIZE/4, 256) # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, IMG_SIZE // 4, IMG_SIZE // 4, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, IMG_SIZE // 2, IMG_SIZE // 2, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(3, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, IMG_SIZE, IMG_SIZE, 3)

    return model

# %%
# using the untrained generator to create an image
generator = make_generator_model()

noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %%
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 102400)            10240000
#
#  batch_normalization (BatchN  (None, 102400)           409600
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 102400)            0
#
#  reshape (Reshape)           (None, 20, 20, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 20, 20, 128)      819200
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 20, 20, 128)      512
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20, 20, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 40, 40, 64)       204800
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 40, 40, 64)       256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 40, 40, 64)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 80, 80, 3)        4800
#  ranspose)
#
# =================================================================
# Total params: 11,679,168
# Trainable params: 11,473,984
# Non-trainable params: 205,184
# _________________________________________________________________

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(IMG_SIZE, IMG_SIZE, 3)),
  ]
)

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()

    model.add(data_augmentation)

    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[IMG_SIZE, IMG_SIZE, 3]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
discriminator = make_discriminator_model()

# %%
discriminator.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 80, 80, 3)         0
#
#  conv2d (Conv2D)             (None, 40, 40, 64)        4864
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 40, 40, 64)        0
#
#  dropout (Dropout)           (None, 40, 40, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 128)       204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 20, 20, 128)       0
#
#  dropout_1 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense_1 (Dense)             (None, 1)                 51201
#
# =================================================================
# Total params: 260,993
# Trainable params: 260,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
EPOCHS = 400
noise_dim = 100
num_examples_to_generate = 8

seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
def train(dataset, epochs):
  for epoch in range(epochs):
    start = time.time()

    for image_batch in dataset:
      train_step(image_batch)

    # Produce images for the GIF as we go
    display.clear_output(wait=True)
    generate_and_save_images(generator, epoch + 1, seed)

    # Save the model every 50 epochs
    if (epoch + 1) % 50 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)

    print (f'Time for epoch {epoch + 1} is {time.time()-start} sec')

  # Generate after the final epoch
  display.clear_output(wait=True)
  generate_and_save_images(generator, epochs, seed)

# %%
def generate_and_save_images(model, epoch, test_input):
    # Notice `training` is set to False.
    # This is so all layers run in inference mode (batchnorm).
    predictions = model(test_input, training=False)

    nrow = 4
    ncol = 4

    fig = plt.figure(figsize=(8, 8))

    gs = gridspec.GridSpec(nrow, ncol,
                           wspace=0.0, hspace=0.0, 
                           top=1.-0.5/(nrow+1), bottom=0.5/(nrow+1), 
                           left=0.5/(ncol+1), right=1-0.5/(ncol+1)) 

    for i in range(predictions.shape[0]):
        plt.subplot(gs[i])
        if predictions.shape[-1] == 3:
            plt.imshow(predictions[i] * 0.5 + .5)                               # scaling the pixel values to floats from 0 to 1
        else: 
            plt.imshow(predictions[i, :, :, 0] * 0.5 + .5, cmap='gray')         # scaling the pixel values to floats from 0 to 1
        plt.axis('off')
    plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
    plt.show()

# %%
train(train_dataset, EPOCHS)
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
anim_file = 'dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('image*.png')
    filenames = sorted(filenames)
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)

# %%
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_file)

# %%
# gif stored locally: might make google collab crash
# Out:
# 'dcgan.gif'
